# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

# Make data: Two circles on x-y plane as a classification problem
X, y = make_circles(n_samples=1000, factor=0.5, noise=0.1)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y.reshape(-1, 1), dtype=torch.float32)
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# Binary classification model
class Model(nn.Module):
    def __init__(self, activation=nn.ReLU):
        super().__init__()
        self.layer0 = nn.Linear(2, 5)
        self.act0 = activation()
        self.layer1 = nn.Linear(5, 5)
        self.act1 = activation()
        self.layer2 = nn.Linear(5, 5)
        self.act2 = activation()
        self.layer3 = nn.Linear(5, 5)
        self.act3 = activation()
        self.layer4 = nn.Linear(5, 1)
        self.act4 = nn.Sigmoid()

    def forward(self, x):
        x = self.act0(self.layer0(x))
        x = self.act1(self.layer1(x))
        x = self.act2(self.layer2(x))
        x = self.act3(self.layer3(x))
        x = self.act4(self.layer4(x))
        return x

# Train the model and produce history
def train_loop(model, X, y, n_epochs=300, batch_size=32):
    loss_fn = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    batch_start = torch.arange(0, len(X), batch_size)

    bce_hist = []
    acc_hist = []
    grad_hist = [[], [], [], [], []]

    for epoch in range(n_epochs):
        # Train model with optimizer
        model.train()
        layer_grad = [[], [], [], [], []]

        for start in batch_start:
            X_batch = X[start:start+batch_size]
            y_batch = y[start:start+batch_size]
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Collect mean absolute value of gradients
            layers = [model.layer0, model.layer1, model.layer2, model.layer3, model.layer4]
            for n, layer in enumerate(layers):
                mean_grad = float(layer.weight.grad.abs().mean())
                layer_grad[n].append(mean_grad)

        # Evaluate BCE and accuracy at the end of each epoch
        model.eval()
        with torch.no_grad():
            y_pred = model(X)
            bce = float(loss_fn(y_pred, y))
            acc = float((y_pred.round() == y).float().mean())
            bce_hist.append(bce)
            acc_hist.append(acc)

            for n, grads in enumerate(layer_grad):
                grad_hist[n].append(sum(grads)/len(grads))

        # Print metrics every 10 epochs
        if epoch % 10 == 9:
            print("Epoch %d: BCE=%.4f, Accuracy=%.2f%%" % (epoch, bce, acc*100))

    return bce_hist, acc_hist, layer_grad

# Pick different activation functions and compare the result visually
for activation in [nn.Sigmoid, nn.Tanh, nn.ReLU, nn.ReLU6, nn.LeakyReLU]:
    model = Model(activation=activation)
    bce_hist, acc_hist, grad_hist = train_loop(model, X, y)

    fig, ax = plt.subplots(1, 2, figsize=(12, 5))
    ax[0].plot(bce_hist, label="BCE")
    ax[0].plot(acc_hist, label="Accuracy")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylim(0, 1)

    for n, grads in enumerate(grad_hist):
        ax[1].plot(grads, label="layer"+str(n))
        ax[1].set_xlabel("Epochs")

    fig.suptitle(str(activation))
    ax[0].legend()
    ax[1].legend()
    plt.show()
# Out:
# Epoch 9: BCE=0.7051, Accuracy=50.00%
# Epoch 19: BCE=0.6994, Accuracy=50.00%
# Epoch 29: BCE=0.6962, Accuracy=50.00%
# Epoch 39: BCE=0.6946, Accuracy=50.00%
# Epoch 49: BCE=0.6938, Accuracy=50.00%
# Epoch 59: BCE=0.6934, Accuracy=50.00%
# Epoch 69: BCE=0.6933, Accuracy=50.00%
# Epoch 79: BCE=0.6932, Accuracy=50.00%
# Epoch 89: BCE=0.6932, Accuracy=50.00%
# Epoch 99: BCE=0.6932, Accuracy=50.00%
# Epoch 109: BCE=0.6931, Accuracy=50.00%
# Epoch 119: BCE=0.6931, Accuracy=50.00%
# Epoch 129: BCE=0.6931, Accuracy=50.00%
# Epoch 139: BCE=0.6931, Accuracy=37.80%
# Epoch 149: BCE=0.6931, Accuracy=54.20%
# Epoch 159: BCE=0.6931, Accuracy=64.00%
# Epoch 169: BCE=0.6931, Accuracy=58.80%
# Epoch 179: BCE=0.6931, Accuracy=54.40%
# Epoch 189: BCE=0.6931, Accuracy=51.50%
# Epoch 199: BCE=0.6931, Accuracy=50.70%
# Epoch 209: BCE=0.6931, Accuracy=50.60%
# Epoch 219: BCE=0.6931, Accuracy=50.50%
# Epoch 229: BCE=0.6931, Accuracy=50.60%
# Epoch 239: BCE=0.6931, Accuracy=50.60%
# Epoch 249: BCE=0.6931, Accuracy=50.70%
# Epoch 259: BCE=0.6931, Accuracy=50.80%
# Epoch 269: BCE=0.6931, Accuracy=51.30%
# Epoch 279: BCE=0.6931, Accuracy=51.80%
# Epoch 289: BCE=0.6931, Accuracy=52.60%
# Epoch 299: BCE=0.6931, Accuracy=53.10%
# Epoch 9: BCE=0.6944, Accuracy=50.00%
# Epoch 19: BCE=0.6933, Accuracy=50.00%
# Epoch 29: BCE=0.6928, Accuracy=50.00%
# Epoch 39: BCE=0.6924, Accuracy=50.00%
# Epoch 49: BCE=0.6920, Accuracy=50.00%
# Epoch 59: BCE=0.6913, Accuracy=51.10%
# Epoch 69: BCE=0.6901, Accuracy=59.10%
# Epoch 79: BCE=0.6880, Accuracy=65.00%
# Epoch 89: BCE=0.6844, Accuracy=70.30%
# Epoch 99: BCE=0.6789, Accuracy=72.50%
# Epoch 109: BCE=0.6712, Accuracy=72.30%
# Epoch 119: BCE=0.6610, Accuracy=72.30%
# Epoch 129: BCE=0.6481, Accuracy=73.30%
# Epoch 139: BCE=0.6326, Accuracy=75.60%
# Epoch 149: BCE=0.6140, Accuracy=78.00%
# Epoch 159: BCE=0.5924, Accuracy=79.50%
# Epoch 169: BCE=0.5685, Accuracy=81.30%
# Epoch 179: BCE=0.5445, Accuracy=82.20%
# Epoch 189: BCE=0.5223, Accuracy=83.20%
# Epoch 199: BCE=0.5032, Accuracy=82.00%
# Epoch 209: BCE=0.4870, Accuracy=81.30%
# Epoch 219: BCE=0.4729, Accuracy=80.90%
# Epoch 229: BCE=0.4600, Accuracy=80.90%
# Epoch 239: BCE=0.4475, Accuracy=81.00%
# Epoch 249: BCE=0.4346, Accuracy=81.00%
# Epoch 259: BCE=0.4206, Accuracy=81.40%
# Epoch 269: BCE=0.4052, Accuracy=82.20%
# Epoch 279: BCE=0.3878, Accuracy=82.90%
# Epoch 289: BCE=0.3684, Accuracy=83.90%
# Epoch 299: BCE=0.3467, Accuracy=85.00%
# Epoch 9: BCE=0.7088, Accuracy=50.00%
# Epoch 19: BCE=0.7055, Accuracy=50.00%
# Epoch 29: BCE=0.7032, Accuracy=50.00%
# Epoch 39: BCE=0.7015, Accuracy=50.00%
# Epoch 49: BCE=0.7000, Accuracy=50.00%
# Epoch 59: BCE=0.6987, Accuracy=50.00%
# Epoch 69: BCE=0.6970, Accuracy=50.00%
# Epoch 79: BCE=0.6953, Accuracy=50.00%
# Epoch 89: BCE=0.6934, Accuracy=50.00%
# Epoch 99: BCE=0.6910, Accuracy=50.00%
# Epoch 109: BCE=0.6882, Accuracy=50.00%
# Epoch 119: BCE=0.6849, Accuracy=50.00%
# Epoch 129: BCE=0.6810, Accuracy=50.00%
# Epoch 139: BCE=0.6765, Accuracy=50.00%
# Epoch 149: BCE=0.6693, Accuracy=73.90%
# Epoch 159: BCE=0.6604, Accuracy=85.10%
# Epoch 169: BCE=0.6502, Accuracy=88.20%
# Epoch 179: BCE=0.6378, Accuracy=90.60%
# Epoch 189: BCE=0.6233, Accuracy=92.20%
# Epoch 199: BCE=0.6065, Accuracy=94.70%
# Epoch 209: BCE=0.5787, Accuracy=95.80%
# Epoch 219: BCE=0.5512, Accuracy=95.70%
# Epoch 229: BCE=0.5230, Accuracy=95.70%
# Epoch 239: BCE=0.4941, Accuracy=96.40%
# Epoch 249: BCE=0.4649, Accuracy=96.60%
# Epoch 259: BCE=0.4355, Accuracy=97.00%
# Epoch 269: BCE=0.4065, Accuracy=97.60%
# Epoch 279: BCE=0.3782, Accuracy=97.70%
# Epoch 289: BCE=0.3509, Accuracy=97.60%
# Epoch 299: BCE=0.3243, Accuracy=97.90%
# Epoch 9: BCE=0.7050, Accuracy=50.00%
# Epoch 19: BCE=0.7016, Accuracy=50.00%
# Epoch 29: BCE=0.7002, Accuracy=50.00%
# Epoch 39: BCE=0.6990, Accuracy=50.00%
# Epoch 49: BCE=0.6981, Accuracy=50.00%
# Epoch 59: BCE=0.6972, Accuracy=50.00%
# Epoch 69: BCE=0.6965, Accuracy=50.00%
# Epoch 79: BCE=0.6958, Accuracy=50.00%
# Epoch 89: BCE=0.6951, Accuracy=50.00%
# Epoch 99: BCE=0.6944, Accuracy=50.00%
# Epoch 109: BCE=0.6937, Accuracy=50.00%
# Epoch 119: BCE=0.6929, Accuracy=50.00%
# Epoch 129: BCE=0.6920, Accuracy=50.00%
# Epoch 139: BCE=0.6909, Accuracy=50.00%
# Epoch 149: BCE=0.6896, Accuracy=50.00%
# Epoch 159: BCE=0.6880, Accuracy=50.00%
# Epoch 169: BCE=0.6862, Accuracy=50.00%
# Epoch 179: BCE=0.6839, Accuracy=50.00%
# Epoch 189: BCE=0.6813, Accuracy=50.00%
# Epoch 199: BCE=0.6782, Accuracy=50.00%
# Epoch 209: BCE=0.6748, Accuracy=50.00%
# Epoch 219: BCE=0.6711, Accuracy=50.00%
# Epoch 229: BCE=0.6670, Accuracy=64.50%
# Epoch 239: BCE=0.6628, Accuracy=66.90%
# Epoch 249: BCE=0.6586, Accuracy=68.50%
# Epoch 259: BCE=0.6545, Accuracy=69.80%
# Epoch 269: BCE=0.6505, Accuracy=71.00%
# Epoch 279: BCE=0.6465, Accuracy=71.70%
# Epoch 289: BCE=0.6425, Accuracy=72.40%
# Epoch 299: BCE=0.6386, Accuracy=73.00%
# Epoch 9: BCE=0.6936, Accuracy=50.00%
# Epoch 19: BCE=0.6934, Accuracy=50.00%
# Epoch 29: BCE=0.6932, Accuracy=50.00%
# Epoch 39: BCE=0.6931, Accuracy=50.00%
# Epoch 49: BCE=0.6930, Accuracy=50.00%
# Epoch 59: BCE=0.6925, Accuracy=50.50%
# Epoch 69: BCE=0.6911, Accuracy=62.00%
# Epoch 79: BCE=0.6892, Accuracy=59.00%
# Epoch 89: BCE=0.6864, Accuracy=60.20%
# Epoch 99: BCE=0.6819, Accuracy=61.40%
# Epoch 109: BCE=0.6762, Accuracy=61.20%
# Epoch 119: BCE=0.6696, Accuracy=61.70%
# Epoch 129: BCE=0.6618, Accuracy=61.30%
# Epoch 139: BCE=0.6532, Accuracy=61.10%
# Epoch 149: BCE=0.6396, Accuracy=60.90%
# Epoch 159: BCE=0.6228, Accuracy=68.00%
# Epoch 169: BCE=0.6075, Accuracy=72.10%
# Epoch 179: BCE=0.5918, Accuracy=74.50%
# Epoch 189: BCE=0.5760, Accuracy=76.00%
# Epoch 199: BCE=0.5607, Accuracy=76.30%
# Epoch 209: BCE=0.5458, Accuracy=76.70%
# Epoch 219: BCE=0.5318, Accuracy=76.40%
# Epoch 229: BCE=0.5188, Accuracy=76.50%
# Epoch 239: BCE=0.5068, Accuracy=77.30%
# Epoch 249: BCE=0.4958, Accuracy=77.40%
# Epoch 259: BCE=0.4856, Accuracy=77.90%
# Epoch 269: BCE=0.4754, Accuracy=78.40%
# Epoch 279: BCE=0.4643, Accuracy=78.80%
# Epoch 289: BCE=0.4513, Accuracy=80.00%
# Epoch 299: BCE=0.4362, Accuracy=80.50%
